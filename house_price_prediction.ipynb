# %%
import pandas as pd

data = pd.read_csv("train.csv")

data.head()

# %%
data.shape

# %%
from sklearn.linear_model import LinearRegression

X = data[['GrLivArea','BedroomAbvGr','FullBath']]
y = data['SalePrice']

model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[2000,3,2]])
# Out:
# c:\Users\Admen\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([243444.31507603])

# %%
from sklearn.metrics import r2_score

y_pred = model.predict(X)
print(r2_score(y, y_pred))
# Out:
# 0.5832212987566321

# %%
import matplotlib.pyplot as plt

plt.scatter(y, y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted House Price")
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [   110.06172639 -27859.33222353  29694.68839062]
# 47509.4821894654
